# %% [markdown]
# <a href="https://colab.research.google.com/github/VENKATB3/Homework/blob/main/Assignment_03/Help_for_hw03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = [2,3,5, 'Sumanth', 'Teja']
print(x)
# Out:
# [2, 3, 5, 'Sumanth', 'Teja']

# %%
for a in x:
   print(x)
# Out:
# [2, 3, 5, 'Sumanth', 'Teja']
# [2, 3, 5, 'Sumanth', 'Teja']
# [2, 3, 5, 'Sumanth', 'Teja']
# [2, 3, 5, 'Sumanth', 'Teja']
# [2, 3, 5, 'Sumanth', 'Teja']

# %%
5 in x
# Out:
# True

# %%
if 5 in x:
   print("5 is a number of a list x.")
else:
   print("5 is not a number")
# Out:
# 5 is a number of a list x.

# %%
y = [5, 1, 5, 6, 2, 7, 8, 6, 4, 2]
print(y)
# Out:
# [5, 1, 5, 6, 2, 7, 8, 6, 4, 2]

# %%
for b in y:
    print(b, end=" ")
# Out:
# 5 1 5 6 2 7 8 6 4 2

# %%
import random

# %%
random.randint(0,9)
# Out:
# 1

# %%
for i in range(0,9):
    print(random.randint(0,9))
# Out:
# 5
# 5
# 3
# 5
# 0
# 4
# 6
# 5
# 8

# %%
for j in range(10):
    for j in range(10):
        print(random.randint(0,9), end=" ")
    print("\n", end="")
print("")
# Out:
# 7 6 5 6 3 4 8 3 7 0
# 6 8 9 4 6 8 6 5 4 3
# 3 0 6 9 5 2 2 0 4 1
# 1 8 7 0 6 0 9 6 4 8
# 5 4 6 4 6 0 1 6 9 9
# 1 3 7 3 5 1 2 3 2 8
# 7 5 2 2 1 8 0 7 5 3
# 1 9 2 4 5 6 8 4 3 2
# 2 5 1 0 5 3 2 2 0 1
# 1 7 6 2 7 4 0 9 0 6
